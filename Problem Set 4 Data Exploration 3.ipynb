# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set(font_scale=1.25)
np.random.seed(5)

pd.set_option("display.max_rows",30000)
pd.set_option("display.max_columns",100)

# %%
df = pd.read_csv("combine3.csv")

# %%
df.head()
# Out:
#    lotarea  bldgarea  comarea  resarea  officearea  retailarea  numbldgs  \
# 0   2500.0    2288.0      0.0   2288.0         0.0         0.0       1.0
# 1   1629.0    1584.0      0.0   1152.0         0.0         0.0       1.0
# 2   1970.0    1485.0      0.0   1080.0         0.0         0.0       1.0
# 3   2500.0    3933.0   1337.0   2596.0         0.0      1337.0       1.0
# 4   1800.0    1701.0      0.0   1188.0         0.0         0.0       1.0
#
#    numfloors  lotdepth  bldgdepth  yearbuilt  builtfar  residfar  commfar  \
# 0        2.0    100.00       52.0     1960.0      0.92      1.25      0.0
# 1        2.0     90.50       32.0     1950.0      0.97      0.75      0.0
# 2        2.0    109.42       32.0     1955.0      0.75      0.75      0.0
# 3        3.0    100.00       60.0     1938.0      1.57      3.00      0.0
# 4        2.0    100.00       33.0     1957.0      0.95      0.75      0.0
#
#    facilfar  complaint_type borough status
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50631 entries, 0 to 50630
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   lotarea         50631 non-null  float64
#  1   bldgarea        50631 non-null  float64
#  2   comarea         50631 non-null  float64
#  3   resarea         50631 non-null  float64
#  4   officearea      50631 non-null  float64
#  5   retailarea      50631 non-null  float64
#  6   numbldgs        50631 non-null  float64
#  7   numfloors       50631 non-null  float64
#  8   lotdepth        50631 non-null  float64
#  9   bldgdepth       50631 non-null  float64
#  10  yearbuilt       50631 non-null  float64
#  11  builtfar        50631 non-null  float64
#  12  residfar        50631 non-null  float64
#  13  commfar         50631 non-null  float64
#  14  facilfar        50631 non-null  float64
#  15  complaint_type  50631 non-null  object
# ...

# %%
df['lotarea'].value_counts()
# Out:
# 2500.0        5869
# 5000.0        2076
# 2375.0        1377
# 2000.0         746
# 1800.0         463
# 10000.0        445
# 3000.0         402
# 4750.0         402
# 3742.0         357
# 2250.0         304
# 2575.0         297
# 7500.0         291
# 4000.0         269
# 1900.0         247
# 2200.0         230
# 2800.0         207
# 2600.0         198
# 3500.0         196
# 2100.0         194
# 3750.0         188
# 2856.0         180
# 2300.0         178
# 2400.0         173
# 3325.0         166
# 2700.0         158
# 2900.0         155
# 4500.0         149
# 1710.0         149
# 2850.0         137
# 3300.0         135
# 3125.0         132
# 2750.0         131
# 2860.0         131
# 1875.0         126
# 15000.0        124
# 2450.0         123
# 2625.0         123
# 12500.0        117
# 1700.0         104
# 3555.0         101
# 3200.0          96
# 2435.0          90
# 3600.0          89
# 2125.0          87
# 2185.0          86
# 3100.0          85
# 1650.0          85
# ...

# %%
df['bldgarea'].value_counts()
# Out:
# 2400.0        358
# 3000.0        294
# 1152.0        281
# 1800.0        275
# 1600.0        257
# 2000.0        230
# 2280.0        219
# 2800.0        218
# 2100.0        215
# 2160.0        212
# 2200.0        206
# 2340.0        206
# 2500.0        203
# 1944.0        190
# 1440.0        182
# 1920.0        179
# 1890.0        170
# 3300.0        165
# 1728.0        163
# 1680.0        160
# 1760.0        158
# 1280.0        157
# 2040.0        147
# 1144.0           5
# 1225.0           5
# 2800.0           5
# 20000.0          5
# ...

# %%
df['retailarea'].value_counts()
# Out:
# 0.0         46038
# 1000.0        111
# 2000.0         94
# 3000.0         92
# 5000.0         92
# 2500.0         82
# 1200.0         71
# 800.0          68
# 1500.0         62
# 1250.0         59
# 4000.0         58
# 625.0          48
# 10000.0        42
# 6000.0         38
# 600.0          38
# 700.0          35
# 1800.0         31
# 1875.0         30
# 1600.0         30
# 500.0          29
# 2400.0         28
# 1050.0         27
# 4500.0         26
# 900.0          26
# 7500.0         25
# 750.0          24
# 3600.0         24
# 3500.0         24
# 1400.0         23
# 2250.0         20
# 1300.0         19
# 1100.0         18
# 400.0          18
# 3750.0         17
# 3400.0         16
# 1900.0         16
# 2200.0         16
# 1750.0         15
# 950.0          14
# 9000.0         14
# 1700.0         14
# 3200.0         13
# 3300.0         13
# 2800.0         12
# 15000.0        12
# 7000.0         12
# 5500.0         12
# 2300.0         12
# 3800.0         11
# 1080.0         11
# ...

# %%
df['numbldgs'].value_counts()
# Out:
# 1.0      39599
# 2.0       9932
# 3.0        673
# 4.0        157
# 0.0         61
# 5.0         60
# 6.0         27
# 7.0         23
# 9.0         12
# 8.0         11
# 10.0         8
# 11.0         5
# 14.0         5
# 15.0         4
# 13.0         3
# 12.0         3
# 18.0         3
# 20.0         3
# 31.0         3
# 39.0         3
# 37.0         2
# 57.0         2
# 26.0         2
# 16.0         2
# 58.0         2
# 17.0         2
# 35.0         2
# 23.0         2
# 21.0         2
# 251.0        1
# 55.0         1
# 22.0         1
# 63.0         1
# 91.0         1
# 145.0        1
# 100.0        1
# 48.0         1
# 29.0         1
# 44.0         1
# 208.0        1
# 69.0         1
# 33.0         1
# 230.0        1
# 19.0         1
# 41.0         1
# 24.0         1
# 30.0         1
# Name: numbldgs, dtype: int64

# %%
df['numfloors'].value_counts()
# Out:
# 2.00     23648
# 3.00      8819
# 1.00      5847
# 2.50      3478
# 5.00      2433
# 6.00      1718
# 4.00      1246
# 1.50      1004
# 2.75       810
# 1.75       475
# 1.67       231
# 7.00       212
# 8.00       155
# 0.00       113
# 9.00        61
# 12.00       53
# 10.00       42
# 3.50        37
# 13.00       35
# 14.00       32
# 11.00       30
# 16.00       22
# 20.00       20
# 2.67        17
# 3.75        15
# 15.00       11
# 19.00        9
# 18.00        9
# 21.00        8
# 2.25         8
# 25.00        5
# 22.00        4
# 17.00        4
# 4.50         3
# 30.00        3
# 28.00        2
# 33.00        2
# 4.30         1
# 5.50         1
# 0.50         1
# 24.00        1
# 26.00        1
# 4.25         1
# 62.00        1
# 1.15         1
# 1.25         1
# 23.00        1
# Name: numfloors, dtype: int64

# %%
df['lotdepth'].value_counts()
# Out:
# 100.00     17495
# 95.00       3504
# 90.00        898
# 103.00       803
# 75.00        502
# 125.00       447
# 50.00        377
# 110.00       374
# 105.00       371
# 114.25       367
# 80.00        339
# 114.42       286
# 85.00        281
# 109.42       252
# 97.42        247
# 120.00       218
# 200.00       212
# 115.00       161
# 70.00        161
# 98.00        153
# 150.00       152
# 87.42        136
# 100.08       132
# 112.00       128
# 114.67       115
# 101.00       109
# 114.17       108
# 99.00        107
# 96.00        105
# 108.25       103
# 94.00        103
# 94.75        102
# 112.42        98
# 100.25        95
# 92.00         93
# 130.00        91
# 114.00        84
# 100.42        83
# 100.50        83
# 97.00         80
# 108.00        79
# 109.00        78
# 100.01        77
# 106.00        77
# 91.00         76
# 87.50         76
# 102.00        75
# 92.42         74
# 111.42        74
# 45.00         73
# 104.00        72
# 97.50         72
# ...

# %%
df['bldgdepth'].value_counts()
# Out:
# 50.00      3025
# 40.00      2289
# 36.00      2191
# 35.00      1658
# 32.00      1488
# 52.00      1475
# 45.00      1465
# 30.00      1401
# 55.00      1372
# 48.00      1229
# 34.00      1186
# 38.00      1161
# 60.00      1150
# 37.00      1145
# 100.00     1052
# 46.00      1008
# 42.00       994
# 33.00       822
# 44.00       740
# 47.00       658
# 54.00       653
# 90.00       630
# 43.00       592
# 56.00       579
# 28.00       573
# 51.00       566
# 39.00       545
# 53.00       503
# 65.00       501
# 88.00       461
# 26.00       453
# 41.00       443
# 49.00       441
# 80.00       440
# 70.00       426
# 25.00       392
# 75.00       385
# 58.00       380
# 24.00       366
# 31.00       354
# 57.00       343
# 62.00       332
# 68.00       303
# 67.00       276
# 87.00       273
# 0.00        272
# 64.00       266
# 85.00       255
# 59.00       229
# 63.00       227
# 27.00       218
# 66.00       215
# 72.00       210
# 61.00       196
# 95.00       195
# ...

# %%
df['builtfar'].value_counts()
# Out:
# 1.00     1049
# 0.75      496
# 0.99      492
# 0.60      489
# 0.67      477
# 0.80      473
# 0.70      468
# 0.72      464
# 0.78      451
# 0.73      443
# 0.74      442
# 0.90      441
# 0.66      437
# 0.69      437
# 0.82      436
# 0.58      436
# 0.50      435
# 0.71      434
# 0.64      434
# 0.59      432
# 0.62      430
# 0.56      426
# 0.61      425
# 0.68      416
# 0.63      415
# 0.77      411
# 0.65      410
# 0.76      406
# 0.81      405
# 0.86      402
# 0.83      398
# 0.85      397
# 0.84      396
# 0.88      396
# 0.95      394
# 0.96      386
# 0.92      384
# 0.94      379
# 0.54      379
# 0.98      378
# 0.48      375
# 0.53      374
# 0.97      374
# 0.79      373
# 0.51      372
# 1.01      371
# 0.52      371
# 0.89      371
# 0.55      360
# 0.87      358
# 0.57      357
# 0.93      349
# 0.91      342
# 0.49      335
# 0.46      334
# 1.02      331
# 0.47      331
# 1.06      322
# 0.44      322
# 1.04      313
# 0.43      306
# 0.42      305
# ...

# %%
df['residfar'].value_counts()
# Out:
# 0.75     14358
# 3.44      7253
# 1.25      7021
# 0.50      6828
# 2.43      6549
# 0.00      2253
# 1.10      1749
# 6.02      1710
# 3.00      1150
# 2.00       633
# 4.00       497
# 1.35       309
# 4.20       145
# 5.00       132
# 7.52        29
# 9.00        11
# 10.00        4
# Name: residfar, dtype: int64

# %%
df['commfar'].value_counts()
# Out:
# 0.0    47233
# 1.0     1254
# 2.0     1199
# 3.4      550
# 0.5      152
# 4.0      124
# 5.0       56
# 4.2       33
# 1   1629.0    1584.0      0.0   1152.0         0.0         0.0       1.0
# 2   1970.0    1485.0      0.0   1080.0         0.0         0.0       1.0
# 3   2500.0    3933.0   1337.0   2596.0         0.0      1337.0       1.0
# 4   1800.0    1701.0      0.0   1188.0         0.0         0.0       1.0
#
#    numfloors  lotdepth  bldgdepth  yearbuilt  builtfar  residfar  commfar  \
# 0        2.0    100.00       52.0     1960.0      0.92      1.25      0.0
# 1        2.0     90.50       32.0     1950.0      0.97      0.75      0.0
# 2        2.0    109.42       32.0     1955.0      0.75      0.75      0.0
# 3        3.0    100.00       60.0     1938.0      1.57      3.00      0.0
# 4        2.0    100.00       33.0     1957.0      0.95      0.75      0.0
#
#    facilfar  complaint_type borough status  year
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50631 entries, 0 to 50630
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   lotarea         50631 non-null  float64
#  1   bldgarea        50631 non-null  float64
#  2   comarea         50631 non-null  float64
#  3   resarea         50631 non-null  float64
#  4   officearea      50631 non-null  float64
#  5   retailarea      50631 non-null  float64
#  6   numbldgs        50631 non-null  float64
#  7   numfloors       50631 non-null  float64
#  8   lotdepth        50631 non-null  float64
#  9   bldgdepth       50631 non-null  float64
#  10  yearbuilt       50631 non-null  float64
#  11  builtfar        50631 non-null  float64
#  12  residfar        50631 non-null  float64
#  13  commfar         50631 non-null  float64
#  14  facilfar        50631 non-null  float64
#  15  complaint_type  50631 non-null  object
# ...

# %%
df = df.drop("yearbuilt",axis=1)

# %%
df.head()
# Out:
#    lotarea  bldgarea  comarea  resarea  officearea  retailarea  numbldgs  \
# 0   2500.0    2288.0      0.0   2288.0         0.0         0.0       1.0
# 1   1629.0    1584.0      0.0   1152.0         0.0         0.0       1.0
# 2   1970.0    1485.0      0.0   1080.0         0.0         0.0       1.0
# 3   2500.0    3933.0   1337.0   2596.0         0.0      1337.0       1.0
# 4   1800.0    1701.0      0.0   1188.0         0.0         0.0       1.0
#
#    numfloors  lotdepth  bldgdepth  builtfar  residfar  commfar  facilfar  \
# 0        2.0    100.00       52.0      0.92      1.25      0.0       2.0
# 1        2.0     90.50       32.0      0.97      0.75      0.0       2.0
# 2        2.0    109.42       32.0      0.75      0.75      0.0       2.0
# 3        3.0    100.00       60.0      1.57      3.00      0.0       3.0
# 4        2.0    100.00       33.0      0.95      0.75      0.0       2.0
#
#    complaint_type borough status  year
# 0  HEAT/HOT WATER   BRONX   Open    60
# ...

# %%
df = df[['lotarea','bldgarea','comarea','resarea','officearea','retailarea','numbldgs','numfloors',
         'lotdepth','bldgdepth','builtfar','residfar','commfar','facilfar','borough',
          'status','year','complaint_type']]

# %%
df.head()
# Out:
#    lotarea  bldgarea  comarea  resarea  officearea  retailarea  numbldgs  \
# 0   2500.0    2288.0      0.0   2288.0         0.0         0.0       1.0
# 1   1629.0    1584.0      0.0   1152.0         0.0         0.0       1.0
# 2   1970.0    1485.0      0.0   1080.0         0.0         0.0       1.0
# 3   2500.0    3933.0   1337.0   2596.0         0.0      1337.0       1.0
# 4   1800.0    1701.0      0.0   1188.0         0.0         0.0       1.0
#
#    numfloors  lotdepth  bldgdepth  builtfar  residfar  commfar  facilfar  \
# 0        2.0    100.00       52.0      0.92      1.25      0.0       2.0
# 1        2.0     90.50       32.0      0.97      0.75      0.0       2.0
# 2        2.0    109.42       32.0      0.75      0.75      0.0       2.0
# 3        3.0    100.00       60.0      1.57      3.00      0.0       3.0
# 4        2.0    100.00       33.0      0.95      0.75      0.0       2.0
#
#   borough status  year  complaint_type
# 0   BRONX   Open    60  HEAT/HOT WATER
# ...

# %%
#Save as csv
#df.to_csv("final3.csv",index=False)

# %%
df1 = pd.read_csv("final3.csv")

# %%
df1.head()
# Out:
#    lotarea  bldgarea  comarea  resarea  officearea  retailarea  numbldgs  \
# 0   2500.0    2288.0      0.0   2288.0         0.0         0.0       1.0
# 1   1629.0    1584.0      0.0   1152.0         0.0         0.0       1.0
# 2   1970.0    1485.0      0.0   1080.0         0.0         0.0       1.0
# 3   2500.0    3933.0   1337.0   2596.0         0.0      1337.0       1.0
# 4   1800.0    1701.0      0.0   1188.0         0.0         0.0       1.0
#
#    numfloors  lotdepth  bldgdepth  builtfar  residfar  commfar  facilfar  \
# 0        2.0    100.00       52.0      0.92      1.25      0.0       2.0
# 1        2.0     90.50       32.0      0.97      0.75      0.0       2.0
# 2        2.0    109.42       32.0      0.75      0.75      0.0       2.0
# 3        3.0    100.00       60.0      1.57      3.00      0.0       3.0
# 4        2.0    100.00       33.0      0.95      0.75      0.0       2.0
#
#   borough status  year  complaint_type
# 0   BRONX   Open    60  HEAT/HOT WATER
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50631 entries, 0 to 50630
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   lotarea         50631 non-null  float64
#  1   bldgarea        50631 non-null  float64
#  2   comarea         50631 non-null  float64
#  3   resarea         50631 non-null  float64
#  4   officearea      50631 non-null  float64
#  5   retailarea      50631 non-null  float64
#  6   numbldgs        50631 non-null  float64
#  7   numfloors       50631 non-null  float64
#  8   lotdepth        50631 non-null  float64
#  9   bldgdepth       50631 non-null  float64
#  10  builtfar        50631 non-null  float64
#  11  residfar        50631 non-null  float64
#  12  commfar         50631 non-null  float64
#  13  facilfar        50631 non-null  float64
#  14  borough         50631 non-null  object
#  15  status          50631 non-null  object
#  16  year            50631 non-null  int64
# ...

# %% [markdown]
# ### Target is Complaint Type, perform Visualization

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='status',hue='complaint_type',data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.barplot(x='complaint_type',y='lotarea',data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.barplot(x='complaint_type',y='bldgarea',data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.barplot(x='complaint_type',y='comarea',data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.barplot(x='complaint_type',y='resarea',data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.barplot(x='complaint_type',y='officearea',data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.barplot(x='complaint_type',y='retailarea',data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.barplot(x='complaint_type',y='numbldgs',data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.barplot(x='complaint_type',y='numfloors',data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.barplot(x='complaint_type',y='lotdepth',data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.barplot(x='complaint_type',y='bldgdepth',data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.barplot(x='complaint_type',y='builtfar',data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.barplot(x='complaint_type',y='residfar',data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.barplot(x='complaint_type',y='commfar',data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.barplot(x='complaint_type',y='facilfar',data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.barplot(x='complaint_type',y='year',data=df1)
plt.xticks(rotation=90)
plt.show()
