# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set(font_scale=1.25)
np.random.seed(5)

pd.set_option("display.max_rows",10000)
pd.set_option("display.max_columns",100)

import pandas_profiling as pp

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler

from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import classification_report, confusion_matrix, plot_confusion_matrix, plot_roc_curve

# %%
df = pd.read_csv("final1.csv")

# %%
df.head()
# Out:
#    complaint_type  incident_zip       street_name  status   lot  lotarea  \
# 0               1       10461.0      NEILL AVENUE  Closed  72.0   1629.0
# 1               1       10463.0     BAILEY AVENUE  Closed  33.0   2500.0
# 2               1       10455.0     TINTON AVENUE    Open   3.0   3034.0
# 3               0       10458.0  EAST  188 STREET    Open  14.0   2500.0
# 4               1       10460.0      MAPES AVENUE    Open  92.0   2025.0
#
#    bldgarea  comarea  resarea  officearea  retailarea  numbldgs  numfloors  \
# 0    1584.0      0.0   1152.0         0.0         0.0       1.0        2.0
# 1    3933.0   1337.0   2596.0         0.0      1337.0       1.0        3.0
# 2    1462.0      0.0   1462.0         0.0         0.0       1.0        2.5
# 3    2133.0      0.0   1512.0         0.0         0.0       1.0        2.0
# 4    2764.0      0.0   2764.0         0.0         0.0       1.0        3.0
#
#    lotdepth  bldgdepth  yearbuilt  builtfar  residfar  commfar  facilfar
# 0     90.50       32.0     1950.0      0.97      0.75      0.0       2.0
# 1    100.00       60.0     1938.0      1.57      3.00      0.0       3.0
# 2     93.58       43.0     1930.0      0.48      0.75      0.0       2.0
# 3    100.00       37.0     1953.0      0.85      0.75      0.0       2.0
# 4    100.00       52.0     1974.0      1.36      0.50      0.0       1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13354 entries, 0 to 13353
# Data columns (total 20 columns):
# complaint_type    13354 non-null int64
# incident_zip      13354 non-null float64
# street_name       13354 non-null object
# status            13354 non-null object
# lot               13354 non-null float64
# lotarea           13354 non-null float64
# bldgarea          13354 non-null float64
# comarea           13354 non-null float64
# resarea           13354 non-null float64
# officearea        13354 non-null float64
# retailarea        13354 non-null float64
# numbldgs          13354 non-null float64
# numfloors         13354 non-null float64
# lotdepth          13354 non-null float64
# bldgdepth         13354 non-null float64
# yearbuilt         13354 non-null float64
# builtfar          13354 non-null float64
# residfar          13354 non-null float64
# commfar           13354 non-null float64
# facilfar          13354 non-null float64
# dtypes: float64(17), int64(1), object(2)
# memory usage: 2.0+ MB

# %%
df.drop(['incident_zip','street_name','lot'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    complaint_type  status  lotarea  bldgarea  comarea  resarea  officearea  \
# 0               1  Closed   1629.0    1584.0      0.0   1152.0         0.0
# 1               1  Closed   2500.0    3933.0   1337.0   2596.0         0.0
# 2               1    Open   3034.0    1462.0      0.0   1462.0         0.0
# 3               0    Open   2500.0    2133.0      0.0   1512.0         0.0
# 4               1    Open   2025.0    2764.0      0.0   2764.0         0.0
#
#    retailarea  numbldgs  numfloors  lotdepth  bldgdepth  yearbuilt  builtfar  \
# 0         0.0       1.0        2.0     90.50       32.0     1950.0      0.97
# 1      1337.0       1.0        3.0    100.00       60.0     1938.0      1.57
# 2         0.0       1.0        2.5     93.58       43.0     1930.0      0.48
# 3         0.0       1.0        2.0    100.00       37.0     1953.0      0.85
# 4         0.0       1.0        3.0    100.00       52.0     1974.0      1.36
#
#    residfar  commfar  facilfar
# 0      0.75      0.0       2.0
# 1      3.00      0.0       3.0
# 2      0.75      0.0       2.0
# 3      0.75      0.0       2.0
# 4      0.50      0.0       1.0

# %%
#Create years column
df['years'] = 2020 - df['yearbuilt'].astype('int')

# %%
df.head()
# Out:
#    complaint_type  status  lotarea  bldgarea  comarea  resarea  officearea  \
# 0               1  Closed   1629.0    1584.0      0.0   1152.0         0.0
# 1               1  Closed   2500.0    3933.0   1337.0   2596.0         0.0
# 2               1    Open   3034.0    1462.0      0.0   1462.0         0.0
# 3               0    Open   2500.0    2133.0      0.0   1512.0         0.0
# 4               1    Open   2025.0    2764.0      0.0   2764.0         0.0
#
#    retailarea  numbldgs  numfloors  lotdepth  bldgdepth  yearbuilt  builtfar  \
# 0         0.0       1.0        2.0     90.50       32.0     1950.0      0.97
# 1      1337.0       1.0        3.0    100.00       60.0     1938.0      1.57
# 2         0.0       1.0        2.5     93.58       43.0     1930.0      0.48
# 3         0.0       1.0        2.0    100.00       37.0     1953.0      0.85
# 4         0.0       1.0        3.0    100.00       52.0     1974.0      1.36
#
#    residfar  commfar  facilfar  years
# 0      0.75      0.0       2.0     70
# 1      3.00      0.0       3.0     82
# 2      0.75      0.0       2.0     90
# 3      0.75      0.0       2.0     67
# 4      0.50      0.0       1.0     46

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13354 entries, 0 to 13353
# Data columns (total 18 columns):
# complaint_type    13354 non-null int64
# status            13354 non-null object
# lotarea           13354 non-null float64
# bldgarea          13354 non-null float64
# comarea           13354 non-null float64
# resarea           13354 non-null float64
# officearea        13354 non-null float64
# retailarea        13354 non-null float64
# numbldgs          13354 non-null float64
# numfloors         13354 non-null float64
# lotdepth          13354 non-null float64
# bldgdepth         13354 non-null float64
# yearbuilt         13354 non-null float64
# builtfar          13354 non-null float64
# residfar          13354 non-null float64
# commfar           13354 non-null float64
# facilfar          13354 non-null float64
# years             13354 non-null int32
# dtypes: float64(15), int32(1), int64(1), object(1)
# memory usage: 1.8+ MB

# %%
df['years'].value_counts()
# Out:
# 100     1234
# 95       958
# 90       908
# 70       760
# 60       715
# 80       591
# 110      567
# 119      563
# 65       557
# 89       514
# 85       387
# 55       385
# 75       265
# 105      251
# 50       248
# 121      224
# 92       168
# 93       166
# 14       136
# 94       133
# 15       128
# 18       113
# 28       111
# 16       104
# 19       100
# 17        99
# 13        96
# 96        92
# 115       91
# 20        91
# 27        88
# 12        84
# 91        82
# 29        82
# 21        75
# 23        73
# 32        71
# 25        70
# 33        70
# 45        68
# 31        60
# 30        54
# 22        47
# 61        43
# 26        43
# 97        40
# 24        38
# 35        38
# 59        38
# 107       37
# 88        35
# 120       33
# 64        32
# 11        32
# 56        32
# 98        32
# 67        31
# 6         31
# 63        31
# 104       29
# 72        29
# 109       28
# 82        28
# 108       28
# 83        27
# 9         27
# 57        27
# 58        26
# 53        25
# 114       25
# 66        24
# 34        24
# 62        24
# 69        23
# 113       23
# 7         23
# 10        23
# 81        22
# 68        22
# 84        21
# 79        21
# 2         20
# 103       20
# 111       20
# 3         20
# 40        19
# 46        19
# 48        17
# 52        17
# 54        17
# 4         16
# 106       16
# 49        16
# 1         16
# 87        15
# 116       15
# 8         14
# 99        14
# 73        14
# 38        14
# 47        13
# 71        13
# 51        12
# 5         11
# 37        11
# 118       11
# 78        10
# 74        10
# 102       10
# 101       10
# 44        10
# 77        10
# 112        9
# 42         9
# 117        8
# 86         8
# 128        7
# 131        7
# 36         6
# 41         6
# 39         6
# 138        5
# 125        5
# 129        5
# 123        4
# 2020       4
# 155        3
# 127        3
# 43         2
# 76         2
# 122        2
# 167        1
# 136        1
# 146        1
# 147        1
# 124        1
# 132        1
# 134        1
# 142        1
# 139        1
# Name: years, dtype: int64

# %%
df.drop(['yearbuilt'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    complaint_type  status  lotarea  bldgarea  comarea  resarea  officearea  \
# 0               1  Closed   1629.0    1584.0      0.0   1152.0         0.0
# 1               1  Closed   2500.0    3933.0   1337.0   2596.0         0.0
# 2               1    Open   3034.0    1462.0      0.0   1462.0         0.0
# 3               0    Open   2500.0    2133.0      0.0   1512.0         0.0
# 4               1    Open   2025.0    2764.0      0.0   2764.0         0.0
#
#    retailarea  numbldgs  numfloors  lotdepth  bldgdepth  builtfar  residfar  \
# 0         0.0       1.0        2.0     90.50       32.0      0.97      0.75
# 1      1337.0       1.0        3.0    100.00       60.0      1.57      3.00
# 2         0.0       1.0        2.5     93.58       43.0      0.48      0.75
# 3         0.0       1.0        2.0    100.00       37.0      0.85      0.75
# 4         0.0       1.0        3.0    100.00       52.0      1.36      0.50
#
#    commfar  facilfar  years
# 0      0.0       2.0     70
# 1      0.0       3.0     82
# 2      0.0       2.0     90
# 3      0.0       2.0     67
# 4      0.0       1.0     46

# %%
df = pd.get_dummies(df,drop_first=True)
df.head()
# Out:
#    complaint_type  lotarea  bldgarea  comarea  resarea  officearea  \
# 0               1   1629.0    1584.0      0.0   1152.0         0.0
# 1               1   2500.0    3933.0   1337.0   2596.0         0.0
# 2               1   3034.0    1462.0      0.0   1462.0         0.0
# 3               0   2500.0    2133.0      0.0   1512.0         0.0
# 4               1   2025.0    2764.0      0.0   2764.0         0.0
#
#    retailarea  numbldgs  numfloors  lotdepth  bldgdepth  builtfar  residfar  \
# 0         0.0       1.0        2.0     90.50       32.0      0.97      0.75
# 1      1337.0       1.0        3.0    100.00       60.0      1.57      3.00
# 2         0.0       1.0        2.5     93.58       43.0      0.48      0.75
# 3         0.0       1.0        2.0    100.00       37.0      0.85      0.75
# 4         0.0       1.0        3.0    100.00       52.0      1.36      0.50
#
#    commfar  facilfar  years  status_Open
# 0      0.0       2.0     70            0
# 1      0.0       3.0     82            0
# 2      0.0       2.0     90            1
# 3      0.0       2.0     67            1
# 4      0.0       1.0     46            1

# %%
df['complaint_type'].value_counts()
# Out:
# 1    6813
# 0    6541
# Name: complaint_type, dtype: int64

# %%
df.rename({'status_Open':'status'},axis=1,inplace=True)

# %%
df.head()
# Out:
#    complaint_type  lotarea  bldgarea  comarea  resarea  officearea  \
# 0               1   1629.0    1584.0      0.0   1152.0         0.0
# 1               1   2500.0    3933.0   1337.0   2596.0         0.0
# 2               1   3034.0    1462.0      0.0   1462.0         0.0
# 3               0   2500.0    2133.0      0.0   1512.0         0.0
# 4               1   2025.0    2764.0      0.0   2764.0         0.0
#
#    retailarea  numbldgs  numfloors  lotdepth  bldgdepth  builtfar  residfar  \
# 0         0.0       1.0        2.0     90.50       32.0      0.97      0.75
# 1      1337.0       1.0        3.0    100.00       60.0      1.57      3.00
# 2         0.0       1.0        2.5     93.58       43.0      0.48      0.75
# 3         0.0       1.0        2.0    100.00       37.0      0.85      0.75
# 4         0.0       1.0        3.0    100.00       52.0      1.36      0.50
#
#    commfar  facilfar  years  status
# 0      0.0       2.0     70       0
# 1      0.0       3.0     82       0
# 2      0.0       2.0     90       1
# 3      0.0       2.0     67       1
# 4      0.0       1.0     46       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13354 entries, 0 to 13353
# Data columns (total 17 columns):
# complaint_type    13354 non-null int64
# lotarea           13354 non-null float64
# bldgarea          13354 non-null float64
# comarea           13354 non-null float64
# resarea           13354 non-null float64
# officearea        13354 non-null float64
# retailarea        13354 non-null float64
# numbldgs          13354 non-null float64
# numfloors         13354 non-null float64
# lotdepth          13354 non-null float64
# bldgdepth         13354 non-null float64
# builtfar          13354 non-null float64
# residfar          13354 non-null float64
# commfar           13354 non-null float64
# facilfar          13354 non-null float64
# years             13354 non-null int32
# status            13354 non-null uint8
# dtypes: float64(14), int32(1), int64(1), uint8(1)
# memory usage: 1.6 MB

# %%
#Rearrange columns
df2 = df[['lotarea','bldgarea','comarea','resarea','officearea','retailarea','numbldgs','numfloors','lotdepth',
          'bldgdepth','builtfar','residfar','commfar','facilfar','years','status','complaint_type']]

# %%
df2.head()
# Out:
#    lotarea  bldgarea  comarea  resarea  officearea  retailarea  numbldgs  \
# 0   1629.0    1584.0      0.0   1152.0         0.0         0.0       1.0
# 1   2500.0    3933.0   1337.0   2596.0         0.0      1337.0       1.0
# 2   3034.0    1462.0      0.0   1462.0         0.0         0.0       1.0
# 3   2500.0    2133.0      0.0   1512.0         0.0         0.0       1.0
# 4   2025.0    2764.0      0.0   2764.0         0.0         0.0       1.0
#
#    numfloors  lotdepth  bldgdepth  builtfar  residfar  commfar  facilfar  \
# 0        2.0     90.50       32.0      0.97      0.75      0.0       2.0
# 1        3.0    100.00       60.0      1.57      3.00      0.0       3.0
# 2        2.5     93.58       43.0      0.48      0.75      0.0       2.0
# 3        2.0    100.00       37.0      0.85      0.75      0.0       2.0
# 4        3.0    100.00       52.0      1.36      0.50      0.0       1.0
#
#    years  status  complaint_type
# 0     70       0               1
# 1     82       0               1
# 2     90       1               1
# 3     67       1               0
# 4     46       1               1

# %%
df2.shape
# Out:
# (13354, 17)

# %%
#pp.ProfileReport(df2)

# %%
#Remove duplicated values
df2.duplicated().sum()
# Out:
# 591

# %%
df3 = df2.drop_duplicates()

# %%
df3.duplicated().sum()
# Out:
# 0

# %%
#Save as csv
#df3.to_csv("train1.csv",index=False)

# %%
df3 = pd.read_csv("train1.csv")

# %%
df3.head()
# Out:
#    lotarea  bldgarea  comarea  resarea  officearea  retailarea  numbldgs  \
# 0   1629.0    1584.0      0.0   1152.0         0.0         0.0       1.0
# 1   2500.0    3933.0   1337.0   2596.0         0.0      1337.0       1.0
# 2   3034.0    1462.0      0.0   1462.0         0.0         0.0       1.0
# 3   2500.0    2133.0      0.0   1512.0         0.0         0.0       1.0
# 4   2025.0    2764.0      0.0   2764.0         0.0         0.0       1.0
#
#    numfloors  lotdepth  bldgdepth  builtfar  residfar  commfar  facilfar  \
# 0        2.0     90.50       32.0      0.97      0.75      0.0       2.0
# 1        3.0    100.00       60.0      1.57      3.00      0.0       3.0
# 2        2.5     93.58       43.0      0.48      0.75      0.0       2.0
# 3        2.0    100.00       37.0      0.85      0.75      0.0       2.0
# 4        3.0    100.00       52.0      1.36      0.50      0.0       1.0
#
#    years  status  complaint_type
# 0     70       0               1
# 1     82       0               1
# 2     90       1               1
# 3     67       1               0
# 4     46       1               1

# %%
df3.describe()
# Out:
#             lotarea      bldgarea       comarea       resarea     officearea  \
# count  1.276300e+04  1.276300e+04  1.276300e+04  1.276300e+04   12763.000000
# mean   1.068883e+04  9.013473e+03  2.445998e+03  6.372704e+03     543.001254
# std    2.532947e+05  4.164870e+04  2.278770e+04  3.350372e+04    8949.576521
# min    3.680000e+02  2.000000e+01  0.000000e+00  0.000000e+00       0.000000
# 25%    2.222000e+03  1.760000e+03  0.000000e+00  1.280000e+03       0.000000
# 50%    2.538000e+03  2.392000e+03  0.000000e+00  1.920000e+03       0.000000
# 75%    4.188000e+03  3.440000e+03  0.000000e+00  2.760000e+03       0.000000
# max    2.225160e+07  2.199075e+06  1.185895e+06  1.965090e+06  480769.000000
#
#           retailarea      numbldgs     numfloors      lotdepth     bldgdepth  \
# count   12763.000000  12763.000000  12763.000000  12763.000000  12763.000000
# mean      441.132179      1.249471      2.481425    104.598569     52.696136
# std      6936.097488      0.930414      1.372565     50.784696     29.438775
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         0.000000      1.000000      2.000000     95.000000     36.000000
# 50%         0.000000      1.000000      2.000000    100.000000     46.000000
# 75%         0.000000      1.000000      3.000000    102.995000     58.000000
# max    464489.000000     55.000000     25.000000   2276.000000    992.000000
#
#            builtfar      residfar       commfar      facilfar         years  \
# count  12763.000000  12763.000000  12763.000000  12763.000000  12763.000000
# mean       1.212561      1.669253      0.114534      2.908337     76.643266
# std        1.052447      1.353845      0.546840      1.593568     45.930095
# min        0.000000      0.000000      0.000000      0.000000      1.000000
# 25%        0.630000      0.750000      0.000000      2.000000     60.000000
# 50%        0.920000      1.250000      0.000000      2.000000     85.000000
# 75%        1.320000      2.430000      0.000000      4.800000    100.000000
# max       16.180000      9.000000      9.000000      9.000000   2020.000000
#
#              status  complaint_type
# count  12763.000000    12763.000000
# mean       0.110711        0.509128
# std        0.313786        0.499936
# min        0.000000        0.000000
# 25%        0.000000        0.000000
# 50%        0.000000        1.000000
# 75%        0.000000        1.000000
# max        1.000000        1.000000

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12763 entries, 0 to 12762
# Data columns (total 17 columns):
# lotarea           12763 non-null float64
# bldgarea          12763 non-null float64
# comarea           12763 non-null float64
# resarea           12763 non-null float64
# officearea        12763 non-null float64
# retailarea        12763 non-null float64
# numbldgs          12763 non-null float64
# numfloors         12763 non-null float64
# lotdepth          12763 non-null float64
# bldgdepth         12763 non-null float64
# builtfar          12763 non-null float64
# residfar          12763 non-null float64
# commfar           12763 non-null float64
# facilfar          12763 non-null float64
# years             12763 non-null int64
# status            12763 non-null int64
# complaint_type    12763 non-null int64
# dtypes: float64(14), int64(3)
# memory usage: 1.7 MB

# %%
scaler = StandardScaler()

# %%
numeric = df3[['lotarea','bldgarea','comarea','resarea','officearea','retailarea','numbldgs','numfloors','lotdepth',
          'bldgdepth','builtfar','residfar','commfar','facilfar','years']]

# %%
numeric
# Out:
#        lotarea  bldgarea  comarea  resarea  officearea  retailarea  numbldgs  \
# 0       1629.0    1584.0      0.0   1152.0         0.0         0.0       1.0
# 1       2500.0    3933.0   1337.0   2596.0         0.0      1337.0       1.0
# 2       3034.0    1462.0      0.0   1462.0         0.0         0.0       1.0
# 3       2500.0    2133.0      0.0   1512.0         0.0         0.0       1.0
# 4       2025.0    2764.0      0.0   2764.0         0.0         0.0       1.0
# ...        ...       ...      ...      ...         ...         ...       ...
# 12758   2500.0    3060.0      0.0   3060.0         0.0         0.0       1.0
# 12759   1638.0    1690.0      0.0   1690.0         0.0         0.0       1.0
# 12760   6730.0   28279.0      0.0  28279.0         0.0         0.0       1.0
# 12761   1741.0    2340.0      0.0   2340.0         0.0         0.0       1.0
# 12762   1764.0    2016.0      0.0   2016.0         0.0         0.0       1.0
#
#        numfloors  lotdepth  bldgdepth  builtfar  residfar  commfar  facilfar  \
# 0            2.0     90.50      32.00      0.97      0.75      0.0       2.0
# 1            3.0    100.00      60.00      1.57      3.00      0.0       3.0
# 2            2.5     93.58      43.00      0.48      0.75      0.0       2.0
# 3            2.0    100.00      37.00      0.85      0.75      0.0       2.0
# 4            3.0    100.00      52.00      1.36      0.50      0.0       1.0
# ...          ...       ...        ...       ...       ...      ...       ...
# 12758        3.0    100.00      60.00      1.22      0.75      0.0       2.0
# 12759        3.0     91.00      35.00      1.03      1.25      0.0       2.0
# 12760        6.0     67.25      55.00      4.20      3.44      0.0       4.8
# 12761        3.0     92.72      40.00      1.34      3.44      0.0       4.8
# 12762        3.0     98.00      36.42      1.14      0.75      0.0       2.0
#
#        years
# 0         70
# 1         82
# 2         90
# 3         67
# 4         46
# ...      ...
# 12758     14
# 12759     70
# 12760     97
# 12761     28
# 12762     60
#
# [12763 rows x 15 columns]

# %%
scalednum = scaler.fit_transform(numeric)

# %%
scalednum
# Out:
# array([[-0.03576934, -0.17839125, -0.10734276, ..., -0.20945552,
#         -0.57002413, -0.14464429],
#        [-0.03233052, -0.12198872, -0.04866845, ..., -0.20945552,
#          0.05752312,  0.11663255],
#        [-0.03022222, -0.18132063, -0.10734276, ..., -0.20945552,
#         -0.57002413,  0.29081711],
#        ...,
#        [-0.01562996,  0.46259021, -0.10734276, ..., -0.20945552,
#          1.18710816,  0.4432286 ],
#        [-0.03532715, -0.16023871, -0.10734276, ..., -0.20945552,
#          1.18710816, -1.05911323],
#        [-0.03523634, -0.16801837, -0.10734276, ..., -0.20945552,
#         -0.57002413, -0.36237499]])

# %%
scalednumX = pd.DataFrame(data=scalednum, columns=numeric.columns)

# %%
scalednumX
# Out:
#         lotarea  bldgarea   comarea   resarea  officearea  retailarea  \
# 0     -0.035769 -0.178391 -0.107343 -0.155831   -0.060676   -0.063602
# 1     -0.032331 -0.121989 -0.048668 -0.112729   -0.060676    0.129165
# 2     -0.030222 -0.181321 -0.107343 -0.146578   -0.060676   -0.063602
# 3     -0.032331 -0.165209 -0.107343 -0.145085   -0.060676   -0.063602
# 4     -0.034206 -0.150058 -0.107343 -0.107715   -0.060676   -0.063602
# ...         ...       ...       ...       ...         ...         ...
# 12758 -0.032331 -0.142951 -0.107343 -0.098880   -0.060676   -0.063602
# 12759 -0.035734 -0.175846 -0.107343 -0.139772   -0.060676   -0.063602
# 12760 -0.015630  0.462590 -0.107343  0.653872   -0.060676   -0.063602
# 12761 -0.035327 -0.160239 -0.107343 -0.120371   -0.060676   -0.063602
# 12762 -0.035236 -0.168018 -0.107343 -0.130042   -0.060676   -0.063602
#
#        numbldgs  numfloors  lotdepth  bldgdepth  builtfar  residfar   commfar  \
# 0      -0.26814  -0.350762 -0.277625  -0.703051 -0.230482 -0.679021 -0.209456
# 1      -0.26814   0.377829 -0.090554   0.248113  0.339640  0.982978 -0.209456
# 2      -0.26814   0.013533 -0.216975  -0.329379 -0.696082 -0.679021 -0.209456
# 3      -0.26814  -0.350762 -0.090554  -0.533200 -0.344506 -0.679021 -0.209456
# 4      -0.26814   0.377829 -0.090554  -0.023648  0.140098 -0.863687 -0.209456
# ...         ...        ...       ...        ...       ...       ...       ...
# 12758  -0.26814   0.377829 -0.090554   0.248113  0.007069 -0.679021 -0.209456
# 12759  -0.26814   0.377829 -0.267780  -0.601140 -0.173470 -0.309688 -0.209456
# 12760  -0.26814   2.563603 -0.735458   0.078263  2.838676  1.307991 -0.209456
# 12761  -0.26814   0.377829 -0.233910  -0.431289  0.121093  1.307991 -0.209456
# 12762  -0.26814   0.377829 -0.129937  -0.552903 -0.068947 -0.679021 -0.209456
#
#        facilfar     years
# 0     -0.570024 -0.144644
# 1      0.057523  0.116633
# 2     -0.570024  0.290817
# 3     -0.570024 -0.209963
# 4     -1.197571 -0.667198
# ...         ...       ...
# 12758 -0.570024 -1.363936
# 12759 -0.570024 -0.144644
# 12760  1.187108  0.443229
# 12761  1.187108 -1.059113
# 12762 -0.570024 -0.362375
#
# [12763 rows x 15 columns]

# %%
category = df3[['status','complaint_type']]

# %%
category
# Out:
#        status  complaint_type
# 0           0               1
# 1           0               1
# 2           1               1
# 3           1               0
# 4           1               1
# ...       ...             ...
# 12758       0               1
# 12759       0               1
# 12760       0               1
# 12761       0               1
# 12762       0               1
#
# [12763 rows x 2 columns]

# %%
df4 = pd.concat([scalednumX,category],axis=1)

# %%
df4.head()
# Out:
#     lotarea  bldgarea   comarea   resarea  officearea  retailarea  numbldgs  \
# 0 -0.035769 -0.178391 -0.107343 -0.155831   -0.060676   -0.063602  -0.26814
# 1 -0.032331 -0.121989 -0.048668 -0.112729   -0.060676    0.129165  -0.26814
# 2 -0.030222 -0.181321 -0.107343 -0.146578   -0.060676   -0.063602  -0.26814
# 3 -0.032331 -0.165209 -0.107343 -0.145085   -0.060676   -0.063602  -0.26814
# 4 -0.034206 -0.150058 -0.107343 -0.107715   -0.060676   -0.063602  -0.26814
#
#    numfloors  lotdepth  bldgdepth  builtfar  residfar   commfar  facilfar  \
# 0  -0.350762 -0.277625  -0.703051 -0.230482 -0.679021 -0.209456 -0.570024
# 1   0.377829 -0.090554   0.248113  0.339640  0.982978 -0.209456  0.057523
# 2   0.013533 -0.216975  -0.329379 -0.696082 -0.679021 -0.209456 -0.570024
# 3  -0.350762 -0.090554  -0.533200 -0.344506 -0.679021 -0.209456 -0.570024
# 4   0.377829 -0.090554  -0.023648  0.140098 -0.863687 -0.209456 -1.197571
#
#       years  status  complaint_type
# 0 -0.144644       0               1
# 1  0.116633       0               1
# 2  0.290817       1               1
# 3 -0.209963       1               0
# 4 -0.667198       1               1

# %%
df4.describe()
# Out:
#             lotarea      bldgarea       comarea       resarea    officearea  \
# count  1.276300e+04  1.276300e+04  1.276300e+04  1.276300e+04  1.276300e+04
# mean  -4.453114e-17  5.317118e-18  3.114050e-15  2.767076e-16  1.178320e-15
# std    1.000039e+00  1.000039e+00  1.000039e+00  1.000039e+00  1.000039e+00
# min   -4.074792e-02 -2.159449e-01 -1.073428e-01 -1.902163e-01 -6.067578e-02
# 25%   -3.342810e-02 -1.741653e-01 -1.073428e-01 -1.520101e-01 -6.067578e-02
# 50%   -3.218049e-02 -1.589901e-01 -1.073428e-01 -1.329070e-01 -6.067578e-02
# 75%   -2.566609e-02 -1.338263e-01 -1.073428e-01 -1.078342e-01 -6.067578e-02
# max    8.780989e+01  5.258621e+01  5.193572e+01  5.846498e+01  5.366118e+01
#
#          retailarea      numbldgs     numfloors      lotdepth     bldgdepth  \
# count  1.276300e+04  1.276300e+04  1.276300e+04  1.276300e+04  1.276300e+04
# mean   2.752082e-15 -2.928351e-16  2.845661e-15  1.108786e-15 -9.684419e-16
# std    1.000039e+00  1.000039e+00  1.000039e+00  1.000039e+00  1.000039e+00
# min   -6.360197e-02 -1.342972e+00 -1.807945e+00 -2.059728e+00 -1.790095e+00
# 25%   -6.360197e-02 -2.681397e-01 -3.507622e-01 -1.890126e-01 -5.671700e-01
# 50%   -6.360197e-02 -2.681397e-01 -3.507622e-01 -9.055384e-02 -2.274687e-01
# 75%   -6.360197e-02 -2.681397e-01  3.778291e-01 -3.157707e-02  1.801730e-01
# max    6.690593e+01  5.777281e+01  1.640684e+01  4.275868e+01  3.190828e+01
#
#            builtfar      residfar       commfar      facilfar         years  \
# count  1.276300e+04  1.276300e+04  1.276300e+04  1.276300e+04  1.276300e+04
# mean   2.557751e-16 -4.461604e-15  1.188834e-15  4.343118e-16 -8.710071e-17
# std    1.000039e+00  1.000039e+00  1.000039e+00  1.000039e+00  1.000039e+00
# min   -1.152180e+00 -1.233020e+00 -2.094555e-01 -1.825119e+00 -1.646986e+00
# 25%   -5.535512e-01 -6.790206e-01 -2.094555e-01 -5.700241e-01 -3.623750e-01
# 50%   -2.779921e-01 -3.096876e-01 -2.094555e-01 -5.700241e-01  1.819518e-01
# 75%    1.020894e-01  5.619383e-01 -2.094555e-01  1.187108e+00  5.085478e-01
# max    1.422212e+01  5.414974e+00  1.624938e+01  3.822807e+00  4.231284e+01
#
#              status  complaint_type
# count  12763.000000    12763.000000
# mean       0.110711        0.509128
# std        0.313786        0.499936
# min        0.000000        0.000000
# 25%        0.000000        0.000000
# 50%        0.000000        1.000000
# 75%        0.000000        1.000000
# max        1.000000        1.000000

# %%
#Save as csv
#df4.to_csv("train1processed.csv",index=False)

# %%
#pp.ProfileReport(df4)
