# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set(font_scale=1.25)
np.random.seed(5)

pd.set_option("display.max_rows",10000)
pd.set_option("display.max_columns",100)

# %%
#Load first dataset
df1 = pd.read_csv("nycheatbronx.csv")

# %%
df1.head()
# Out:
#    unique_key             created_date              closed_date  \
# 0    45538988  2020-02-03T05:53:31.000  2020-02-03T16:54:52.000
# 1    45540022  2020-02-03T18:01:48.000                      NaN
# 2    45539035  2020-02-03T06:54:49.000  2020-02-03T17:06:54.000
# 3    45539982  2020-02-03T12:31:16.000                      NaN
# 4    45539989  2020-02-03T17:25:12.000                      NaN
#
#    complaint_type         location_type  zipcode        incident_address  \
# 0  HEAT/HOT WATER  RESIDENTIAL BUILDING  10461.0       1185 NEILL AVENUE
# 1  HEAT/HOT WATER  RESIDENTIAL BUILDING  10468.0  2523 UNIVERSITY AVENUE
# 2  HEAT/HOT WATER  RESIDENTIAL BUILDING  10463.0      3150 BAILEY AVENUE
# 3  HEAT/HOT WATER  RESIDENTIAL BUILDING  10455.0       520 TINTON AVENUE
# 4  HEAT/HOT WATER  RESIDENTIAL BUILDING  10460.0       2112 MAPES AVENUE
#
#          street_name address_type   city  status  \
# 0       NEILL AVENUE      ADDRESS  BRONX  Closed
# 1  UNIVERSITY AVENUE      ADDRESS  BRONX    Open
# 2      BAILEY AVENUE      ADDRESS  BRONX  Closed
# 3      TINTON AVENUE      ADDRESS  BRONX    Open
# 4       MAPES AVENUE      ADDRESS  BRONX    Open
#
#                               resolution_description borough   latitude  \
# 0  The Department of Housing Preservation and Dev...   BRONX  40.855078
# 1  The following complaint conditions are still o...   BRONX  40.866135
# 2  The Department of Housing Preservation and Dev...   BRONX  40.878790
# 3  The following complaint conditions are still o...   BRONX  40.812037
# 4  The following complaint conditions are still o...   BRONX  40.846939
#
#    longitude
# 0 -73.852492
# 1 -73.902726
# 2 -73.901771
# 3 -73.906544
# 4 -73.885253

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17330 entries, 0 to 17329
# Data columns (total 15 columns):
# unique_key                17330 non-null int64
# created_date              17330 non-null object
# closed_date               17064 non-null object
# complaint_type            17330 non-null object
# location_type             17330 non-null object
# zipcode                   17326 non-null float64
# incident_address          17330 non-null object
# street_name               17330 non-null object
# address_type              17330 non-null object
# city                      17326 non-null object
# status                    17330 non-null object
# resolution_description    17329 non-null object
# borough                   17330 non-null object
# latitude                  17326 non-null float64
# longitude                 17326 non-null float64
# dtypes: float64(3), int64(1), object(11)
# memory usage: 2.0+ MB

# %%
df1.shape
# Out:
# (17330, 15)

# %%
df1['city'].value_counts()
# Out:
# BRONX    17326
# Name: city, dtype: int64

# %%
df1['borough'].value_counts()
# Out:
# BRONX    17330
# Name: borough, dtype: int64

# %% [markdown]
# ### Drop unnecessary features first

# %%
df1.drop(columns=['unique_key','created_date','closed_date','complaint_type','location_type','incident_address',
                  'address_type','city','status','resolution_description','borough'],inplace=True, axis=1)

# %%
df1
# Out:
#        zipcode              street_name   latitude  longitude
# 0      10461.0             NEILL AVENUE  40.855078 -73.852492
# 1      10468.0        UNIVERSITY AVENUE  40.866135 -73.902726
# 2      10463.0            BAILEY AVENUE  40.878790 -73.901771
# 3      10455.0            TINTON AVENUE  40.812037 -73.906544
# 4      10460.0             MAPES AVENUE  40.846939 -73.885253
# ...        ...                      ...        ...        ...
# 17325  10458.0         EAST  187 STREET  40.856385 -73.889152
# 17326  10459.0  REV JAMES POLITE AVENUE  40.818750 -73.898886
# 17327  10460.0         EAST  179 STREET  40.842428 -73.880584
# 17328  10462.0         PARKCHESTER ROAD  40.836695 -73.859511
# 17329  10463.0            OXFORD AVENUE  40.886026 -73.908863
#
# [17330 rows x 4 columns]

# %%
df1['address'] = df1['street_name'].str.replace('\d+', '')

# %%
df1
# Out:
#        zipcode              street_name   latitude  longitude  \
# 0      10461.0             NEILL AVENUE  40.855078 -73.852492
# 1      10468.0        UNIVERSITY AVENUE  40.866135 -73.902726
# 2      10463.0            BAILEY AVENUE  40.878790 -73.901771
# 3      10455.0            TINTON AVENUE  40.812037 -73.906544
# 4      10460.0             MAPES AVENUE  40.846939 -73.885253
# ...        ...                      ...        ...        ...
# 17325  10458.0         EAST  187 STREET  40.856385 -73.889152
# 17326  10459.0  REV JAMES POLITE AVENUE  40.818750 -73.898886
# 17327  10460.0         EAST  179 STREET  40.842428 -73.880584
# 17328  10462.0         PARKCHESTER ROAD  40.836695 -73.859511
# 17329  10463.0            OXFORD AVENUE  40.886026 -73.908863
#
#                        address
# 0                 NEILL AVENUE
# 1            UNIVERSITY AVENUE
# 2                BAILEY AVENUE
# 3                TINTON AVENUE
# 4                 MAPES AVENUE
# ...                        ...
# 17325            EAST   STREET
# 17326  REV JAMES POLITE AVENUE
# 17327            EAST   STREET
# 17328         PARKCHESTER ROAD
# 17329            OXFORD AVENUE
#
# [17330 rows x 5 columns]

# %%
df1.drop(columns='street_name',axis=1,inplace=True)

# %%
df1
# Out:
#        zipcode   latitude  longitude                  address
# 0      10461.0  40.855078 -73.852492             NEILL AVENUE
# 1      10468.0  40.866135 -73.902726        UNIVERSITY AVENUE
# 2      10463.0  40.878790 -73.901771            BAILEY AVENUE
# 3      10455.0  40.812037 -73.906544            TINTON AVENUE
# 4      10460.0  40.846939 -73.885253             MAPES AVENUE
# ...        ...        ...        ...                      ...
# 17325  10458.0  40.856385 -73.889152            EAST   STREET
# 17326  10459.0  40.818750 -73.898886  REV JAMES POLITE AVENUE
# 17327  10460.0  40.842428 -73.880584            EAST   STREET
# 17328  10462.0  40.836695 -73.859511         PARKCHESTER ROAD
# 17329  10463.0  40.886026 -73.908863            OXFORD AVENUE
#
# [17330 rows x 4 columns]

# %%
#Save to csv
#df1.to_csv("left.csv",index=False)

# %% [markdown]
# ### Load the second dataset and sample 17330 samples

# %%
df2 = pd.read_csv("bronx.csv")

# %%
df2.head()
# Out:
#   borough  lot  zipcode                  address  lotarea  bldgarea  comarea  \
# 0      BX   47  10469.0    3310 BRONXWOOD AVENUE   2500.0    2288.0      0.0
# 1      BX   72  10466.0          4031 ELY AVENUE   1629.0    1584.0      0.0
# 2      BX  183  10466.0      964 EAST 229 STREET   1970.0    1485.0      0.0
# 3      BX   33  10469.0  1006 EAST GUN HILL ROAD   2500.0    3933.0   1337.0
# 4      BX   14  10466.0     3879 AMUNDSON AVENUE   1800.0    1701.0      0.0
#
#    resarea  officearea  retailarea  numbldgs  numfloors  lotdepth  bldgdepth  \
# 0   2288.0         0.0         0.0       1.0        2.0    100.00       52.0
# 1   1152.0         0.0         0.0       1.0        2.0     90.50       32.0
# 2   1080.0         0.0         0.0       1.0        2.0    109.42       32.0
# 3   2596.0         0.0      1337.0       1.0        3.0    100.00       60.0
# 4   1188.0         0.0         0.0       1.0        2.0    100.00       33.0
#
#    yearbuilt  yearalter1  builtfar  residfar  commfar  facilfar   latitude  \
# 0     1960.0         0.0      0.92      1.25      0.0       2.0  40.873572
# 1     1950.0         0.0      0.97      0.75      0.0       2.0  40.890608
# 2     1955.0         0.0      0.75      0.75      0.0       2.0  40.887873
# 3     1938.0         0.0      1.57      3.00      0.0       3.0  40.874358
# 4     1957.0         0.0      0.95      0.75      0.0       2.0  40.888725
#
#    longitude
# 0 -73.860952
# 1 -73.845925
# 2 -73.851034
# 3 -73.857873
# 4 -73.835676

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86157 entries, 0 to 86156
# Data columns (total 22 columns):
# borough       86157 non-null object
# lot           86157 non-null int64
# zipcode       85881 non-null float64
# address       86112 non-null object
# lotarea       86097 non-null float64
# bldgarea      86109 non-null float64
# comarea       79299 non-null float64
# resarea       79299 non-null float64
# officearea    79299 non-null float64
# retailarea    79299 non-null float64
# numbldgs      86097 non-null float64
# numfloors     86097 non-null float64
# lotdepth      86097 non-null float64
# bldgdepth     86097 non-null float64
# yearbuilt     86112 non-null float64
# yearalter1    86112 non-null float64
# builtfar      86061 non-null float64
# residfar      86112 non-null float64
# commfar       86112 non-null float64
# facilfar      86112 non-null float64
# latitude      86034 non-null float64
# longitude     86034 non-null float64
# dtypes: float64(19), int64(1), object(2)
# memory usage: 14.5+ MB

# %%
df2['address2'] = df2['address'].str.replace('\d+', '')

# %%
df2
# Out:
#       borough  lot  zipcode                  address  lotarea  bldgarea  \
# 0          BX   47  10469.0    3310 BRONXWOOD AVENUE   2500.0    2288.0
# 1          BX   72  10466.0          4031 ELY AVENUE   1629.0    1584.0
# 2          BX  183  10466.0      964 EAST 229 STREET   1970.0    1485.0
# 3          BX   33  10469.0  1006 EAST GUN HILL ROAD   2500.0    3933.0
# 4          BX   14  10466.0     3879 AMUNDSON AVENUE   1800.0    1701.0
# ...       ...  ...      ...                      ...      ...       ...
# 86152      BX   58  10462.0       2161 BARNES AVENUE  20008.0   74772.0
# 86153      BX   20  10472.0        1272 NOBLE AVENUE   2500.0    3321.0
# 86154      BX   45  10460.0        1726 ADAMS STREET   4913.0    1932.0
# 86155      BX   17  10461.0    2020 TENBROECK AVENUE   6641.0    1621.0
# 86156      BX   12  10453.0       2157 WALTON AVENUE   1425.0    1406.0
#
#        comarea  resarea  officearea  retailarea  numbldgs  numfloors  \
# 0          0.0   2288.0         0.0         0.0       1.0        2.0
# 1          0.0   1152.0         0.0         0.0       1.0        2.0
# 2          0.0   1080.0         0.0         0.0       1.0        2.0
# 3       1337.0   2596.0         0.0      1337.0       1.0        3.0
# 4          0.0   1188.0         0.0         0.0       1.0        2.0
# ...        ...      ...         ...         ...       ...        ...
# 86152      0.0  74772.0         0.0         0.0       1.0        6.0
# 86153      0.0   3321.0         0.0         0.0       1.0        2.0
# 86154   1932.0      0.0         0.0         0.0       1.0        2.0
# 86155      0.0   1621.0         0.0         0.0       1.0        2.0
# 86156      0.0   1406.0         0.0         0.0       1.0        2.0
#
#        lotdepth  bldgdepth  yearbuilt  yearalter1  builtfar  residfar  \
# 0        100.00       52.0     1960.0         0.0      0.92      1.25
# 1         90.50       32.0     1950.0         0.0      0.97      0.75
# 2        109.42       32.0     1955.0         0.0      0.75      0.75
# 3        100.00       60.0     1938.0         0.0      1.57      3.00
# 4        100.00       33.0     1957.0         0.0      0.95      0.75
# ...         ...        ...        ...         ...       ...       ...
# 86152    100.00       76.0     1931.0         0.0      3.74      3.44
# 86153    100.00       81.0     1926.0         0.0      1.33      1.25
# 86154     98.25       45.0     1942.0         0.0      0.39      1.25
# 86155    121.67       26.0     1940.0         0.0      0.24      0.50
# 86156     75.00       37.0     1901.0         0.0      0.99      6.02
#
#        commfar  facilfar   latitude  longitude             address2
# 0          0.0       2.0  40.873572 -73.860952     BRONXWOOD AVENUE
# 1          0.0       2.0  40.890608 -73.845925           ELY AVENUE
# 2          0.0       2.0  40.887873 -73.851034         EAST  STREET
# 3          0.0       3.0  40.874358 -73.857873   EAST GUN HILL ROAD
# 4          0.0       2.0  40.888725 -73.835676      AMUNDSON AVENUE
# ...        ...       ...        ...        ...                  ...
# 86152      0.0       4.8  40.855241 -73.864135        BARNES AVENUE
# 86153      0.0       2.0  40.832030 -73.869990         NOBLE AVENUE
# 86154      0.0       2.0  40.841328 -73.871066         ADAMS STREET
# 86155      0.0       1.0  40.855852 -73.852111     TENBROECK AVENUE
# 86156      0.0       6.5  40.855693 -73.904729        WALTON AVENUE
#
# [86157 rows x 23 columns]

# %%
df2.drop(columns=['borough','address'],axis=1,inplace=True)

# %%
df2
# Out:
#        lot  zipcode  lotarea  bldgarea  comarea  resarea  officearea  \
# 0       47  10469.0   2500.0    2288.0      0.0   2288.0         0.0
# 1       72  10466.0   1629.0    1584.0      0.0   1152.0         0.0
# 2      183  10466.0   1970.0    1485.0      0.0   1080.0         0.0
# 3       33  10469.0   2500.0    3933.0   1337.0   2596.0         0.0
# 4       14  10466.0   1800.0    1701.0      0.0   1188.0         0.0
# ...    ...      ...      ...       ...      ...      ...         ...
# 86152   58  10462.0  20008.0   74772.0      0.0  74772.0         0.0
# 86153   20  10472.0   2500.0    3321.0      0.0   3321.0         0.0
# 86154   45  10460.0   4913.0    1932.0   1932.0      0.0         0.0
# 86155   17  10461.0   6641.0    1621.0      0.0   1621.0         0.0
# 86156   12  10453.0   1425.0    1406.0      0.0   1406.0         0.0
#
#        retailarea  numbldgs  numfloors  lotdepth  bldgdepth  yearbuilt  \
# 0             0.0       1.0        2.0    100.00       52.0     1960.0
# 1             0.0       1.0        2.0     90.50       32.0     1950.0
# 2             0.0       1.0        2.0    109.42       32.0     1955.0
# 3          1337.0       1.0        3.0    100.00       60.0     1938.0
# 4             0.0       1.0        2.0    100.00       33.0     1957.0
# ...           ...       ...        ...       ...        ...        ...
# 86152         0.0       1.0        6.0    100.00       76.0     1931.0
# 86153         0.0       1.0        2.0    100.00       81.0     1926.0
# 86154         0.0       1.0        2.0     98.25       45.0     1942.0
# 86155         0.0       1.0        2.0    121.67       26.0     1940.0
# 86156         0.0       1.0        2.0     75.00       37.0     1901.0
#
#        yearalter1  builtfar  residfar  commfar  facilfar   latitude  \
# 0             0.0      0.92      1.25      0.0       2.0  40.873572
# 1             0.0      0.97      0.75      0.0       2.0  40.890608
# 2             0.0      0.75      0.75      0.0       2.0  40.887873
# 3             0.0      1.57      3.00      0.0       3.0  40.874358
# 4             0.0      0.95      0.75      0.0       2.0  40.888725
# ...           ...       ...       ...      ...       ...        ...
# 86152         0.0      3.74      3.44      0.0       4.8  40.855241
# 86153         0.0      1.33      1.25      0.0       2.0  40.832030
# 86154         0.0      0.39      1.25      0.0       2.0  40.841328
# 86155         0.0      0.24      0.50      0.0       1.0  40.855852
# 86156         0.0      0.99      6.02      0.0       6.5  40.855693
#
#        longitude             address2
# 0     -73.860952     BRONXWOOD AVENUE
# 1     -73.845925           ELY AVENUE
# 2     -73.851034         EAST  STREET
# 3     -73.857873   EAST GUN HILL ROAD
# 4     -73.835676      AMUNDSON AVENUE
# ...          ...                  ...
# 86152 -73.864135        BARNES AVENUE
# 86153 -73.869990         NOBLE AVENUE
# 86154 -73.871066         ADAMS STREET
# 86155 -73.852111     TENBROECK AVENUE
# 86156 -73.904729        WALTON AVENUE
#
# [86157 rows x 21 columns]

# %%
df2 = df2.rename(columns={'address2':'address'})

# %%
df2
# Out:
#        lot  zipcode  lotarea  bldgarea  comarea  resarea  officearea  \
# 0       47  10469.0   2500.0    2288.0      0.0   2288.0         0.0
# 1       72  10466.0   1629.0    1584.0      0.0   1152.0         0.0
# 2      183  10466.0   1970.0    1485.0      0.0   1080.0         0.0
# 3       33  10469.0   2500.0    3933.0   1337.0   2596.0         0.0
# 4       14  10466.0   1800.0    1701.0      0.0   1188.0         0.0
# ...    ...      ...      ...       ...      ...      ...         ...
# 86152   58  10462.0  20008.0   74772.0      0.0  74772.0         0.0
# 86153   20  10472.0   2500.0    3321.0      0.0   3321.0         0.0
# 86154   45  10460.0   4913.0    1932.0   1932.0      0.0         0.0
# 86155   17  10461.0   6641.0    1621.0      0.0   1621.0         0.0
# 86156   12  10453.0   1425.0    1406.0      0.0   1406.0         0.0
#
#        retailarea  numbldgs  numfloors  lotdepth  bldgdepth  yearbuilt  \
# 0             0.0       1.0        2.0    100.00       52.0     1960.0
# 1             0.0       1.0        2.0     90.50       32.0     1950.0
# 2             0.0       1.0        2.0    109.42       32.0     1955.0
# 3          1337.0       1.0        3.0    100.00       60.0     1938.0
# 4             0.0       1.0        2.0    100.00       33.0     1957.0
# ...           ...       ...        ...       ...        ...        ...
# 86152         0.0       1.0        6.0    100.00       76.0     1931.0
# 86153         0.0       1.0        2.0    100.00       81.0     1926.0
# 86154         0.0       1.0        2.0     98.25       45.0     1942.0
# 86155         0.0       1.0        2.0    121.67       26.0     1940.0
# 86156         0.0       1.0        2.0     75.00       37.0     1901.0
#
#        yearalter1  builtfar  residfar  commfar  facilfar   latitude  \
# 0             0.0      0.92      1.25      0.0       2.0  40.873572
# 1             0.0      0.97      0.75      0.0       2.0  40.890608
# 2             0.0      0.75      0.75      0.0       2.0  40.887873
# 3             0.0      1.57      3.00      0.0       3.0  40.874358
# 4             0.0      0.95      0.75      0.0       2.0  40.888725
# ...           ...       ...       ...      ...       ...        ...
# 86152         0.0      3.74      3.44      0.0       4.8  40.855241
# 86153         0.0      1.33      1.25      0.0       2.0  40.832030
# 86154         0.0      0.39      1.25      0.0       2.0  40.841328
# 86155         0.0      0.24      0.50      0.0       1.0  40.855852
# 86156         0.0      0.99      6.02      0.0       6.5  40.855693
#
#        longitude              address
# 0     -73.860952     BRONXWOOD AVENUE
# 1     -73.845925           ELY AVENUE
# 2     -73.851034         EAST  STREET
# 3     -73.857873   EAST GUN HILL ROAD
# 4     -73.835676      AMUNDSON AVENUE
# ...          ...                  ...
# 86152 -73.864135        BARNES AVENUE
# 86153 -73.869990         NOBLE AVENUE
# 86154 -73.871066         ADAMS STREET
# 86155 -73.852111     TENBROECK AVENUE
# 86156 -73.904729        WALTON AVENUE
#
# [86157 rows x 21 columns]

# %%
df2 = df2.sample(n=17330)

# %%
df2
# Out:
#        lot  zipcode  lotarea  bldgarea  comarea  resarea  officearea  \
# 80661   39  10466.0   2000.0    2080.0      0.0   2080.0         0.0
# 83279  149  10465.0   1823.0    1499.0      0.0   1499.0         0.0
# 66128  136  10453.0   1500.0    3423.0      0.0   3423.0         0.0
# 83266   56  10469.0   1900.0    1911.0      0.0   1344.0         0.0
# 54651   57  10461.0   2500.0    1536.0      0.0   1536.0         0.0
# ...    ...      ...      ...       ...      ...      ...         ...
# 44763   76  10465.0   1800.0    1998.0      0.0   1998.0         0.0
# 27459  150  10459.0   2147.0    2280.0      0.0   2280.0         0.0
# 85095    7  10461.0   1676.0    1676.0   1676.0      0.0         0.0
# 14685   11  10455.0   3900.0   15414.0      0.0  15414.0         0.0
# 8091    20  10469.0   2731.0       0.0      NaN      NaN         NaN
#
#        retailarea  numbldgs  numfloors  lotdepth  bldgdepth  yearbuilt  \
# 80661         0.0       1.0        2.0    100.00      52.00     2005.0
# 83279         0.0       1.0        2.0     50.00      36.00     1940.0
# 66128         0.0       1.0        3.0    100.00      37.00     2007.0
# 83266         0.0       1.0        2.0    100.00      40.00     1965.0
# 54651         0.0       1.0        2.5    100.00      36.00     1920.0
# ...           ...       ...        ...       ...        ...        ...
# 44763         0.0       1.0        3.0    100.00      37.00     1960.0
# 27459         0.0       1.0        3.0    100.00      40.00     1991.0
# 85095      1676.0       1.0        1.0     60.75      60.00     1928.0
# 14685         0.0       1.0        6.0    100.00      86.67     1906.0
# 8091          NaN       1.0        0.0    109.25       0.00     1950.0
#
#        yearalter1  builtfar  residfar  commfar  facilfar   latitude  \
# 80661         0.0      1.04      0.75      0.0       2.0  40.896076
# 83279         0.0      0.82      0.75      0.0       2.0  40.813435
# 66128         0.0      2.28      3.44      0.0       4.8  40.848281
# 83266      1998.0      1.01      0.75      0.0       2.0  40.866312
# 54651         0.0      0.61      0.75      0.0       2.0  40.847051
# ...           ...       ...       ...      ...       ...        ...
# 44763         0.0      1.11      0.50      0.0       1.0  40.815113
# 27459         0.0      1.06      3.44      0.0       6.5  40.828625
# 85095         0.0      1.00      3.44      0.0       4.8  40.844162
# 14685      1995.0      3.95      2.43      0.0       4.8  40.820495
# 8091          0.0      0.00      0.75      0.0       2.0  40.878864
#
#        longitude             address
# 80661 -73.839879      BUSSING AVENUE
# 83279 -73.822838       SCHURZ AVENUE
# 66128 -73.913303     DAVIDSON AVENUE
# 83266 -73.858935     PAULDING AVENUE
# 54651 -73.852947         HONE AVENUE
# ...          ...                 ...
# 44763 -73.821479   HUNTINGTON AVENUE
# 27459 -73.895601        EAST  STREET
# 85095 -73.830079     MIDDLETOWN ROAD
# 14685 -73.915185        EAST  STREET
# 8091  -73.854978        EAST  STREET
#
# [17330 rows x 21 columns]

# %%
#df2.to_csv('right.csv',index=False)

# %% [markdown]
# ### Merge the two datasets

# %%
df1 = pd.read_csv("left.csv")

# %%
df1.head()
# Out:
#    zipcode   latitude  longitude            address
# 0  10461.0  40.855078 -73.852492       NEILL AVENUE
# 1  10468.0  40.866135 -73.902726  UNIVERSITY AVENUE
# 2  10463.0  40.878790 -73.901771      BAILEY AVENUE
# 3  10455.0  40.812037 -73.906544      TINTON AVENUE
# 4  10460.0  40.846939 -73.885253       MAPES AVENUE

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17330 entries, 0 to 17329
# Data columns (total 4 columns):
# zipcode      17326 non-null float64
# latitude     17326 non-null float64
# longitude    17326 non-null float64
# address      17330 non-null object
# dtypes: float64(3), object(1)
# memory usage: 541.7+ KB

# %%
df2 = pd.read_csv("right.csv")

# %%
df2.head()
# Out:
#    lot  zipcode  lotarea  bldgarea  comarea  resarea  officearea  retailarea  \
# 0   39  10466.0   2000.0    2080.0      0.0   2080.0         0.0         0.0
# 1  149  10465.0   1823.0    1499.0      0.0   1499.0         0.0         0.0
# 2  136  10453.0   1500.0    3423.0      0.0   3423.0         0.0         0.0
# 3   56  10469.0   1900.0    1911.0      0.0   1344.0         0.0         0.0
# 4   57  10461.0   2500.0    1536.0      0.0   1536.0         0.0         0.0
#
#    numbldgs  numfloors  lotdepth  bldgdepth  yearbuilt  yearalter1  builtfar  \
# 0       1.0        2.0     100.0       52.0     2005.0         0.0      1.04
# 1       1.0        2.0      50.0       36.0     1940.0         0.0      0.82
# 2       1.0        3.0     100.0       37.0     2007.0         0.0      2.28
# 3       1.0        2.0     100.0       40.0     1965.0      1998.0      1.01
# 4       1.0        2.5     100.0       36.0     1920.0         0.0      0.61
#
#    residfar  commfar  facilfar   latitude  longitude           address
# 0      0.75      0.0       2.0  40.896076 -73.839879    BUSSING AVENUE
# 1      0.75      0.0       2.0  40.813435 -73.822838     SCHURZ AVENUE
# 2      3.44      0.0       4.8  40.848281 -73.913303   DAVIDSON AVENUE
# 3      0.75      0.0       2.0  40.866312 -73.858935   PAULDING AVENUE
# 4      0.75      0.0       2.0  40.847051 -73.852947       HONE AVENUE

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17330 entries, 0 to 17329
# Data columns (total 21 columns):
# lot           17330 non-null int64
# zipcode       17270 non-null float64
# lotarea       17318 non-null float64
# bldgarea      17319 non-null float64
# comarea       15895 non-null float64
# resarea       15895 non-null float64
# officearea    15895 non-null float64
# retailarea    15895 non-null float64
# numbldgs      17318 non-null float64
# numfloors     17318 non-null float64
# lotdepth      17318 non-null float64
# bldgdepth     17318 non-null float64
# yearbuilt     17320 non-null float64
# yearalter1    17320 non-null float64
# builtfar      17313 non-null float64
# residfar      17320 non-null float64
# commfar       17320 non-null float64
# facilfar      17320 non-null float64
# latitude      17306 non-null float64
# longitude     17306 non-null float64
# address       17320 non-null object
# dtypes: float64(19), int64(1), object(1)
# memory usage: 2.8+ MB

# %%
df3 = df1.join(df2,lsuffix='_left',rsuffix='_right')

# %%
df3
# Out:
#        zipcode_left  latitude_left  longitude_left             address_left  \
# 0           10461.0      40.855078      -73.852492             NEILL AVENUE
# 1           10468.0      40.866135      -73.902726        UNIVERSITY AVENUE
# 2           10463.0      40.878790      -73.901771            BAILEY AVENUE
# 3           10455.0      40.812037      -73.906544            TINTON AVENUE
# 4           10460.0      40.846939      -73.885253             MAPES AVENUE
# ...             ...            ...             ...                      ...
# 17325       10458.0      40.856385      -73.889152            EAST   STREET
# 17326       10459.0      40.818750      -73.898886  REV JAMES POLITE AVENUE
# 17327       10460.0      40.842428      -73.880584            EAST   STREET
# 17328       10462.0      40.836695      -73.859511         PARKCHESTER ROAD
# 17329       10463.0      40.886026      -73.908863            OXFORD AVENUE
#
#        lot  zipcode_right  lotarea  bldgarea  comarea  resarea  officearea  \
# 0       39        10466.0   2000.0    2080.0      0.0   2080.0         0.0
# 1      149        10465.0   1823.0    1499.0      0.0   1499.0         0.0
# 2      136        10453.0   1500.0    3423.0      0.0   3423.0         0.0
# 3       56        10469.0   1900.0    1911.0      0.0   1344.0         0.0
# 4       57        10461.0   2500.0    1536.0      0.0   1536.0         0.0
# ...    ...            ...      ...       ...      ...      ...         ...
# 17325   76        10465.0   1800.0    1998.0      0.0   1998.0         0.0
# 17326  150        10459.0   2147.0    2280.0      0.0   2280.0         0.0
# 17327    7        10461.0   1676.0    1676.0   1676.0      0.0         0.0
# 17328   11        10455.0   3900.0   15414.0      0.0  15414.0         0.0
# 17329   20        10469.0   2731.0       0.0      NaN      NaN         NaN
#
#        retailarea  numbldgs  numfloors  lotdepth  bldgdepth  yearbuilt  \
# 0             0.0       1.0        2.0    100.00      52.00     2005.0
# 1             0.0       1.0        2.0     50.00      36.00     1940.0
# 2             0.0       1.0        3.0    100.00      37.00     2007.0
# 3             0.0       1.0        2.0    100.00      40.00     1965.0
# 4             0.0       1.0        2.5    100.00      36.00     1920.0
# ...           ...       ...        ...       ...        ...        ...
# 17325         0.0       1.0        3.0    100.00      37.00     1960.0
# 17326         0.0       1.0        3.0    100.00      40.00     1991.0
# 17327      1676.0       1.0        1.0     60.75      60.00     1928.0
# 17328         0.0       1.0        6.0    100.00      86.67     1906.0
# 17329         NaN       1.0        0.0    109.25       0.00     1950.0
#
#        yearalter1  builtfar  residfar  commfar  facilfar  latitude_right  \
# 0             0.0      1.04      0.75      0.0       2.0       40.896076
# 1             0.0      0.82      0.75      0.0       2.0       40.813435
# 2             0.0      2.28      3.44      0.0       4.8       40.848281
# 3          1998.0      1.01      0.75      0.0       2.0       40.866312
# 4             0.0      0.61      0.75      0.0       2.0       40.847051
# ...           ...       ...       ...      ...       ...             ...
# 17325         0.0      1.11      0.50      0.0       1.0       40.815113
# 17326         0.0      1.06      3.44      0.0       6.5       40.828625
# 17327         0.0      1.00      3.44      0.0       4.8       40.844162
# 17328      1995.0      3.95      2.43      0.0       4.8       40.820495
# 17329         0.0      0.00      0.75      0.0       2.0       40.878864
#
#        longitude_right       address_right
# 0           -73.839879      BUSSING AVENUE
# 1           -73.822838       SCHURZ AVENUE
# 2           -73.913303     DAVIDSON AVENUE
# 3           -73.858935     PAULDING AVENUE
# 4           -73.852947         HONE AVENUE
# ...                ...                 ...
# 17325       -73.821479   HUNTINGTON AVENUE
# 17326       -73.895601        EAST  STREET
# 17327       -73.830079     MIDDLETOWN ROAD
# 17328       -73.915185        EAST  STREET
# 17329       -73.854978        EAST  STREET
#
# [17330 rows x 25 columns]

# %%
#Save to csv
#df3.to_csv("combine.csv",index=False)

# %%
#df3 = pd.concat([df1,df2],axis=1)

# %%
#df3 = pd.merge(left=df1,right=df2,left_on='address',right_on='address',how='outer')
