# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set(font_scale=1.25)
np.random.seed(5)

pd.set_option("display.max_rows",10000)
pd.set_option("display.max_columns",100)

# %%
#Load first dataset
df1 = pd.read_csv("nycbronx1.csv")

# %%
df1.head()
# Out:
#    unique_key             created_date  complaint_type         location_type  \
# 0    45539181  2020-02-03T12:53:54.000               0  RESIDENTIAL BUILDING
# 1    45538988  2020-02-03T05:53:31.000               1  RESIDENTIAL BUILDING
# 2    45540022  2020-02-03T18:01:48.000               1  RESIDENTIAL BUILDING
# 3    45539035  2020-02-03T06:54:49.000               1  RESIDENTIAL BUILDING
# 4    45540010  2020-02-03T08:28:50.000               0  RESIDENTIAL BUILDING
#
#    incident_zip        incident_address        street_name address_type  \
# 0       10466.0   4040 CARPENTER AVENUE   CARPENTER AVENUE      ADDRESS
# 1       10461.0       1185 NEILL AVENUE       NEILL AVENUE      ADDRESS
# 2       10468.0  2523 UNIVERSITY AVENUE  UNIVERSITY AVENUE      ADDRESS
# 3       10463.0      3150 BAILEY AVENUE      BAILEY AVENUE      ADDRESS
# 4       10467.0       679 WARING AVENUE      WARING AVENUE      ADDRESS
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33759 entries, 0 to 33758
# Data columns (total 14 columns):
# unique_key                33759 non-null int64
# created_date              33759 non-null object
# complaint_type            33759 non-null int64
# location_type             33759 non-null object
# incident_zip              33759 non-null float64
# incident_address          33759 non-null object
# street_name               33759 non-null object
# address_type              33759 non-null object
# city                      33759 non-null object
# status                    33759 non-null object
# resolution_description    33759 non-null object
# borough                   33759 non-null object
# latitude                  33759 non-null float64
# longitude                 33759 non-null float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 3.6+ MB

# %%
df1.shape
# Out:
# (33759, 14)

# %%
#Save to csv
#df1.to_csv("left1.csv",index=False)

# %% [markdown]
# ### Load the second dataset and sample 17330 samples

# %%
df2 = pd.read_csv("bronx.csv")

# %%
df2.head()
# Out:
#   borough  lot  zipcode                  address  lotarea  bldgarea  comarea  \
# 0      BX   47  10469.0    3310 BRONXWOOD AVENUE   2500.0    2288.0      0.0
# 1      BX   72  10466.0          4031 ELY AVENUE   1629.0    1584.0      0.0
# 2      BX  183  10466.0      964 EAST 229 STREET   1970.0    1485.0      0.0
# 3      BX   33  10469.0  1006 EAST GUN HILL ROAD   2500.0    3933.0   1337.0
# 4      BX   14  10466.0     3879 AMUNDSON AVENUE   1800.0    1701.0      0.0
#
#    resarea  officearea  retailarea  numbldgs  numfloors  lotdepth  bldgdepth  \
# 0   2288.0         0.0         0.0       1.0        2.0    100.00       52.0
# 1   1152.0         0.0         0.0       1.0        2.0     90.50       32.0
# 2   1080.0         0.0         0.0       1.0        2.0    109.42       32.0
# 3   2596.0         0.0      1337.0       1.0        3.0    100.00       60.0
# 4   1188.0         0.0         0.0       1.0        2.0    100.00       33.0
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86157 entries, 0 to 86156
# Data columns (total 22 columns):
# borough       86157 non-null object
# lot           86157 non-null int64
# zipcode       85881 non-null float64
# address       86112 non-null object
# lotarea       86097 non-null float64
# bldgarea      86109 non-null float64
# comarea       79299 non-null float64
# resarea       79299 non-null float64
# officearea    79299 non-null float64
# retailarea    79299 non-null float64
# numbldgs      86097 non-null float64
# numfloors     86097 non-null float64
# lotdepth      86097 non-null float64
# bldgdepth     86097 non-null float64
# yearbuilt     86112 non-null float64
# yearalter1    86112 non-null float64
# builtfar      86061 non-null float64
# residfar      86112 non-null float64
# commfar       86112 non-null float64
# facilfar      86112 non-null float64
# latitude      86034 non-null float64
# longitude     86034 non-null float64
# ...

# %%
df2.isnull().sum()
# Out:
# borough          0
# lot              0
# zipcode        276
# address         45
# lotarea         60
# bldgarea        48
# comarea       6858
# resarea       6858
# officearea    6858
# retailarea    6858
# numbldgs        60
# numfloors       60
# lotdepth        60
# bldgdepth       60
# yearbuilt       45
# yearalter1      45
# builtfar        96
# residfar        45
# commfar         45
# facilfar        45
# latitude       123
# longitude      123
# dtype: int64

# %%
#Discard all NaNs
df2.dropna(inplace=True)

# %%
df2.shape
# Out:
# (79266, 22)

# %%
df2.isnull().sum()
# Out:
# borough       0
# lot           0
# zipcode       0
# address       0
# lotarea       0
# bldgarea      0
# comarea       0
# resarea       0
# officearea    0
# retailarea    0
# numbldgs      0
# numfloors     0
# lotdepth      0
# bldgdepth     0
# yearbuilt     0
# yearalter1    0
# builtfar      0
# residfar      0
# commfar       0
# facilfar      0
# latitude      0
# longitude     0
# dtype: int64

# %%
df2
# Out:
#       borough  lot  zipcode                  address  lotarea  bldgarea  \
# 0          BX   47  10469.0    3310 BRONXWOOD AVENUE   2500.0    2288.0
# 1          BX   72  10466.0          4031 ELY AVENUE   1629.0    1584.0
# 2          BX  183  10466.0      964 EAST 229 STREET   1970.0    1485.0
# 3          BX   33  10469.0  1006 EAST GUN HILL ROAD   2500.0    3933.0
# 4          BX   14  10466.0     3879 AMUNDSON AVENUE   1800.0    1701.0
# ...       ...  ...      ...                      ...      ...       ...
# 86152      BX   58  10462.0       2161 BARNES AVENUE  20008.0   74772.0
# 86153      BX   20  10472.0        1272 NOBLE AVENUE   2500.0    3321.0
# 86154      BX   45  10460.0        1726 ADAMS STREET   4913.0    1932.0
# 86155      BX   17  10461.0    2020 TENBROECK AVENUE   6641.0    1621.0
# 86156      BX   12  10453.0       2157 WALTON AVENUE   1425.0    1406.0
#
#        comarea  resarea  officearea  retailarea  numbldgs  numfloors  \
# ...

# %%
#Save to csv
#df2.to_csv("bronxfilled.csv",index=False)

# %%
df2 = df2.sample(n=33759)

# %%
df2.head()
# Out:
#       borough  lot  zipcode                address  lotarea  bldgarea  \
# 47616      BX   21  10459.0    1144 TIFFANY STREET  14148.0   62890.0
# 65433      BX  161  10474.0    621 BARRETTO STREET   3208.0    3360.0
# 34826      BX   53  10460.0      853 ELSMERE PLACE   9620.0   43302.0
# 27535      BX  136  10469.0  2949 TENBROECK AVENUE   2500.0    1260.0
# 39808      BX   62  10469.0    960 ALLERTON AVENUE  16326.0    1904.0
#
#        comarea  resarea  officearea  retailarea  numbldgs  numfloors  \
# 47616   3500.0  59390.0         0.0         0.0       1.0        8.0
# 65433      0.0   3360.0         0.0         0.0       1.0        2.0
# 34826    930.0  42372.0         0.0       930.0       1.0        5.0
# 27535      0.0   1260.0         0.0         0.0       1.0        2.0
# 39808   1904.0      0.0       112.0      1792.0       2.0        1.0
#
#        lotdepth  bldgdepth  yearbuilt  yearalter1  builtfar  residfar  \
# ...

# %%
df2.shape
# Out:
# (33759, 22)

# %%
#df2.to_csv('right.csv',index=False)

# %% [markdown]
# ### Merge the two datasets

# %%
df3 = df1.join(df2,lsuffix='_left',rsuffix='_right',how='left')

# %%
df3
# Out:
#        unique_key             created_date  complaint_type  \
# 0        45539181  2020-02-03T12:53:54.000               0
# 1        45538988  2020-02-03T05:53:31.000               1
# 2        45540022  2020-02-03T18:01:48.000               1
# 3        45539035  2020-02-03T06:54:49.000               1
# 4        45540010  2020-02-03T08:28:50.000               0
# ...           ...                      ...             ...
# 33754    45138841  2019-12-11T11:14:16.000               1
# 33755    45138803  2019-12-11T15:07:14.000               1
# 33756    45138068  2019-12-11T12:31:58.000               1
# 33757    45138035  2019-12-11T11:25:45.000               1
# 33758    45138015  2019-12-11T11:16:32.000               1
#
#               location_type  incident_zip             incident_address  \
# 0      RESIDENTIAL BUILDING       10466.0        4040 CARPENTER AVENUE
# 1      RESIDENTIAL BUILDING       10461.0            1185 NEILL AVENUE
# ...

# %%
df3.duplicated().sum()
# Out:
# 0

# %%
df3.isnull().sum()
# Out:
# unique_key                    0
# created_date                  0
# complaint_type                0
# location_type                 0
# incident_zip                  0
# incident_address              0
# street_name                   0
# address_type                  0
# city                          0
# status                        0
# resolution_description        0
# borough_left                  0
# latitude_left                 0
# longitude_left                0
# borough_right             20405
# lot                       20405
# zipcode                   20405
# address                   20405
# lotarea                   20405
# bldgarea                  20405
# comarea                   20405
# resarea                   20405
# officearea                20405
# retailarea                20405
# numbldgs                  20405
# numfloors                 20405
# lotdepth                  20405
# bldgdepth                 20405
# yearbuilt                 20405
# ...

# %%
#Discard all NaNs
df3.dropna(inplace=True)

# %%
df3
# Out:
#        unique_key             created_date  complaint_type  \
# 1        45538988  2020-02-03T05:53:31.000               1
# 3        45539035  2020-02-03T06:54:49.000               1
# 5        45539982  2020-02-03T12:31:16.000               1
# 7        45539193  2020-02-03T17:49:22.000               0
# 8        45539989  2020-02-03T17:25:12.000               1
# ...           ...                      ...             ...
# 33741    45140488  2019-12-12T05:13:48.000               1
# 33743    45140466  2019-12-12T17:00:45.000               1
# 33749    45139740  2019-12-11T10:59:46.000               1
# 33755    45138803  2019-12-11T15:07:14.000               1
# 33758    45138015  2019-12-11T11:16:32.000               1
#
#               location_type  incident_zip             incident_address  \
# 1      RESIDENTIAL BUILDING       10461.0            1185 NEILL AVENUE
# 3      RESIDENTIAL BUILDING       10463.0           3150 BAILEY AVENUE
# ...

# %%
df3.shape
# Out:
# (13354, 36)

# %%
df3['complaint_type'].value_counts()
# Out:
# 1    6813
# 0    6541
# Name: complaint_type, dtype: int64

# %%
#Save to csv
#df3.to_csv("combine1.csv",index=False)

# %%
df1.shape
# Out:
# (33759, 14)

# %%
df2.shape
# Out:
# (33759, 22)

# %%
df5 = pd.concat([df1,df2],axis=1)

# %%
df5
# Out:
#        unique_key             created_date  complaint_type  \
# 0      45539181.0  2020-02-03T12:53:54.000             0.0
# 1      45538988.0  2020-02-03T05:53:31.000             1.0
# 2      45540022.0  2020-02-03T18:01:48.000             1.0
# 3      45539035.0  2020-02-03T06:54:49.000             1.0
# 4      45540010.0  2020-02-03T08:28:50.000             0.0
# ...           ...                      ...             ...
# 86146         NaN                      NaN             NaN
# 86148         NaN                      NaN             NaN
# 86152         NaN                      NaN             NaN
# 86154         NaN                      NaN             NaN
# 86156         NaN                      NaN             NaN
#
#               location_type  incident_zip        incident_address  \
# 0      RESIDENTIAL BUILDING       10466.0   4040 CARPENTER AVENUE
# 1      RESIDENTIAL BUILDING       10461.0       1185 NEILL AVENUE
# ...

# %%
df5.dropna(inplace=True)

# %%
df5.shape
# Out:
# (13354, 36)

# %%
#df3 = pd.merge(left=df1,right=df2,left_on='address',right_on='address',how='outer')
